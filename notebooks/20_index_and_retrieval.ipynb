# %% [markdown]
# # Index and retrieval
#
# Benchmark FAISS+BM25 retrieval and optional LanceDB backend.

# %%
from pathlib import Path

from polyglot_grounded_qa import create_default_pipeline

pipeline = create_default_pipeline(str(Path('..').resolve()))
result = pipeline.run('What is language-pack architecture?', language='base')
result
# Out:
# GroundedAnswer(answer="Based on the retrieved evidence, relevant context for 'What is language-pack architecture?' is: Polyglot grounded QA uses retrieval with citations and verification.", citations=[Citation(doc_id='seed-doc-1', chunk_id='seed-chunk-1', span=None)], claims=[], abstained=False, metadata={'generator': 'baseline'})
