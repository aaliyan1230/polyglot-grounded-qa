# %% [markdown]
# # Eval harness
#
# Run retrieval and answer-level metrics and persist run artifacts.

# %%
import subprocess
from pathlib import Path

root = Path('..').resolve()
subprocess.run(['uv', 'run', 'python', 'scripts/run_eval.py'], cwd=root, check=True)
# Out:
# Wrote 2 eval rows to /Users/aaliyan/aaliyan/polyglot-grounded-qa/artifacts/runs/eval_results.parquet
# CompletedProcess(args=['uv', 'run', 'python', 'scripts/run_eval.py'], returncode=0)
