# %% [markdown]
# # Ablations
#
# Compare baseline vs no-rerank (placeholder ablation runner).

# %%
import subprocess
from pathlib import Path

root = Path('..').resolve()
subprocess.run(['uv', 'run', 'python', 'scripts/run_ablation.py'], cwd=root, check=True)
# Out:
# Wrote 2 ablation rows to /Users/aaliyan/aaliyan/polyglot-grounded-qa/artifacts/tables/ablation_results.parquet
# CompletedProcess(args=['uv', 'run', 'python', 'scripts/run_ablation.py'], returncode=0)
