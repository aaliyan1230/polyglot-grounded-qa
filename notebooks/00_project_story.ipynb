# %% [markdown]
# # polyglot-grounded-qa story
#
# This notebook introduces the research objective: language-pack-first grounded QA with citations, verification, and abstention.

# %% [markdown]
# ## Narrative checkpoints
#
# 1. Build a reusable core pipeline.
# 2. Add trust-layer verification and abstention.
# 3. Compare language packs and ablations.
