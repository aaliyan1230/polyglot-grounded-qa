# %% [markdown]
# # Data ingestion
#
# Load corpora and benchmarks using a shared schema across languages.

# %%
from pathlib import Path

root = Path('..').resolve()
print(root)
# Out:
# /Users/aaliyan/aaliyan/polyglot-grounded-qa
