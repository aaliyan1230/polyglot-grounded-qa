# %% [markdown]
# # Language packs
#
# Inspect inheritance behavior for base, tr, es, es-MX, and fr.

# %%
from pathlib import Path

from polyglot_grounded_qa.core.config_loader import load_app_config

cfg = load_app_config(Path('..').resolve())
{k: v.parent for k, v in cfg.languages.items()}
