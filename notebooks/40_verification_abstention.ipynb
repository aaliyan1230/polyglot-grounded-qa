# %% [markdown]
# # Verification and abstention
#
# Evaluate claim support and abstention behavior under low evidence conditions.

# %%
from pathlib import Path

from polyglot_grounded_qa import create_default_pipeline

pipeline = create_default_pipeline(str(Path('..').resolve()))
result = pipeline.run('Unanswerable test query', language='base')
result.abstained
