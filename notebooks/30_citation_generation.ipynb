# %% [markdown]
# # Citation-aware generation
#
# Inspect structured answers and citation bindings.

# %%
from pathlib import Path

from polyglot_grounded_qa import create_default_pipeline

pipeline = create_default_pipeline(str(Path('..').resolve()))
answer = pipeline.run('Why cite evidence in QA?', language='base')
answer.model_dump()
