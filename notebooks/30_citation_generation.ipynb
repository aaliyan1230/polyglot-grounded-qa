# %% [markdown]
# # Citation-aware generation
#
# Inspect structured answers and citation bindings.

# %%
from pathlib import Path

from polyglot_grounded_qa import create_default_pipeline

pipeline = create_default_pipeline(str(Path('..').resolve()))
answer = pipeline.run('Why cite evidence in QA?', language='base')
answer.model_dump()
# Out:
# {'answer': "Based on the retrieved evidence, relevant context for 'Why cite evidence in QA?' is: Polyglot grounded QA uses retrieval with citations and verification.",
#  'citations': [{'doc_id': 'seed-doc-1',
#    'chunk_id': 'seed-chunk-1',
#    'span': None}],
#  'claims': [],
#  'abstained': False,
#  'metadata': {'generator': 'baseline'}}
